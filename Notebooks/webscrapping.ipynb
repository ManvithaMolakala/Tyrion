# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://docs.starknet.io/staking/overview/"

# %%
page = requests.get(url)

# %%
BeautifulSoup(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <title>Staking Overview :: Starknet documentation</title>
# <link href="https://docs.starknet.io/staking/overview/" rel="canonical"/>
# <link href="../../quick-start/troubleshooting/" rel="prev"/>
# <link href="../entering-staking/" rel="next"/>
# <meta content="Antora 3.1.1" name="generator"/>
# <!-- Primary Meta Tags -->
# <meta content="Starknet Documentation" name="title"/>
# <meta content="Reference documentation for developers building on Starknet." name="description"/>
# <!-- Open Graph / Facebook -->
# <meta content="article" property="og:type"/>
# <meta content="https://docs.starknet.io/" property="og:url"/>
# <meta content="Starknet Documentation" property="og:title"/>
# <meta content="Reference documentation for developers building on Starknet." property="og:description"/>
# ...
